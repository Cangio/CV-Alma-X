# %% [markdown]
# # programmatically run cells
#
# **issues** if subsequent code is located in a cell that should wait another one to execute, it may fail (too slow)
#
# cursor moves to the run cell
#
# https://stackoverflow.com/questions/47567834/execute-a-jupyter-notebook-cell-programmatically
#
# https://stackoverflow.com/questions/32267540/ipython-jupyter-can-we-program-a-run-all-cell-above

# %%
print('byee world')
# Out:
# byee world

# %%
import cv2 as cv
import matplotlib.pyplot as plt
print('hello world')
# Out:
# hello world

# %%
from IPython.display import Javascript
import time
display(Javascript('IPython.notebook.execute_cells([1])'))
#display(Javascript('IPython.notebook.execute_cells_above()'))
image=cv.imread('../../images/3dpanel/panelpersp_smooth.jpg')
plt.imshow(image)
plt.show()
